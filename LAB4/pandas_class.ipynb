# %%
# %matplotlib inline
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;

# %%
dataset=pd.read_csv("iris.csv")
dataset
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
dataset.plot(kind='scatter',x='sepal.length',y='sepal.width')
# Out:
# <AxesSubplot: xlabel='sepal.length', ylabel='sepal.width'>

# %%
dataset.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
plt.scatter(dataset.index,dataset['sepal.width'])

# %%
plt.figure(figsize=(6,6))
plt.title('Line plot of petal length')
plt.xlabel('index',fontsize=20)
plt.ylabel('petal length',fontsize=20)
plt.plot(dataset.index,dataset['petal.length'],markevery=1,marker='d')
for name,group in dataset.groupby('variety'):
    plt.plot(group.index,group['petal.length'],label=name,markevery=1,marker='d')
plt.legend()
plt.show()

# %%
plt.hist(dataset['petal.length']);

# %%
dataset['petal.length'].plot(kind='density');

# %%
plt.boxplot(dataset['sepal.width']);

# %%
print(dataset.corr())
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_4328\4187620694.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(dataset.corr())

# %%
import seaborn as sb

dataplot = sb.heatmap(dataset.corr(), cmap="YlGnBu", annot=True);
  
plt.show();
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_4328\317142692.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sb.heatmap(dataset.corr(), cmap="YlGnBu", annot=True);
