# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('iris.csv')

# %%
data = pd.read('iris.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read('iris.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('iris.csv')

# %%
data
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
data.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.6/7.6 MB 185.4 kB/s eta 0:00:00
# ...
#      -------------------------------------- 55.3/55.3 KB 239.5 kB/s eta 0:00:00
# ...
#      ------------------------------------ 965.4/965.4 KB 283.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 299.9 kB/s eta 0:00:00
# ...
#      -------------------------------------- 98.3/98.3 KB 234.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 163.0/163.0 KB 279.2 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\ronit\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install seaborn
# Out:
# ...
#      ------------------------------------ 293.3/293.3 KB 904.3 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\ronit\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
plt.scatter(df.index,data['sepal.width'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plt.scatter(df.index,data['sepal.width'])
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
pip install scanner
# Out:
# ...
#      -------------------------------------- 575.6/575.6 KB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [10 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\ronit\AppData\Local\Temp\pip-install-mdd2pqr8\scanner_dbe810b3011b43b3b0c934b74c7de10b\setup.py", line 29, in <module>
#           popen = Popen(configure_options, stdout=PIPE, stderr=PIPE)
#         File "c:\Users\ronit\AppData\Local\Programs\Python\Python310\lib\subprocess.py", line 969, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
plt.scatter(data.index,data['sepal.width'])
plt.show()

# %%
sns.scatterplot(x=data.index,y=data['sepal.width'],hue=data['variety'])
# Out:
# <Axes: ylabel='sepal.width'>

# %%
plt.figure(figsize=(6,6))
plt.title('Line plot of petal length')
plt.xlabel('index',fontsize=20)
plt.ylabel('petal length',fontsize=20)
plt.plot(data.index,data['petal.length'],markevery=1,marker='d')
for name, group in data.groupby('variety'):
    plt.plot(group.index, group['petal.length'], label=name,markevery=1,marker='d')
plt.legend()
plt.show()

# %%
sns.stripplot(y=data['sepal.width'])
# Out:
# <Axes: ylabel='sepal.width'>

# %%
sns.stripplot(x=data['variety'],y=data['sepal.width'])
# Out:
# <Axes: xlabel='variety', ylabel='sepal.width'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.swarmplot(x=data['sepal.width'])
# Out:
# <Axes: xlabel='sepal.width'>

# %%
plt.hist(data['petal.width'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
#density plots

# %%
plt.figure(figsize=(5,5))
data['petal.length'].plot(kind='density')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.figure(figsize=(5,5))
# ----> 2 data['petal.length'].plot(kind='density')
#
# File c:\Users\ronit\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\ronit\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
pip install scipy
# Out:
# ...
#
# ...
#      --                                       2.3/42.5 MB 21.7 kB/s eta 0:30:48
# ERROR: THESE PACKAGES DO NOT MATCH THE HASHES FROM THE REQUIREMENTS FILE. If you have updated the package versions, please update the hashes. Otherwise, examine the package contents carefully; someone may have tampered with them.
#     scipy from https://files.pythonhosted.org/packages/ec/e3/b06ac3738bf365e89710205a471abe7dceec672a51c244b469bc5d1291c7/scipy-1.10.1-cp310-cp310-win_amd64.whl#sha256=fae8a7b898c42dffe3f7361c40d5952b6bf32d10c4569098d276b4c547905ee1:
#         Expected sha256 fae8a7b898c42dffe3f7361c40d5952b6bf32d10c4569098d276b4c547905ee1
#              Got        eb621f54263290ccb65b49f27d1076e4c739435596755be597cd873b0cb7eec4
#
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\ronit\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
plt.boxplot(data['sepal.width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2adedc23b80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2adedc44100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2adedc238e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2adedc44640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2adedc448e0>],
#  'means': []}

# %%
plt.figure(figsize=(9,9))
plt.title('Box plots of the 4 variables')
plt.boxplot(dataM.values,labels=['SepalLength','SepalWidth','PetalLength','PetalWidth'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 plt.figure(figsize=(9,9))
#       2 plt.title('Box plots of the 4 variables')
# ----> 3 plt.boxplot(dataM.values,labels=['SepalLength','SepalWidth','PetalLength','PetalWidth'])
#
# NameError: name 'dataM' is not defined

# %%
plt.figure(figsize=(9,9))
plt.title('Box plots of the 4 variables')
plt.boxplot(data.values,labels=['SepalLength','SepalWidth','PetalLength','PetalWidth'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 plt.figure(figsize=(9,9))
#       2 plt.title('Box plots of the 4 variables')
# ----> 3 plt.boxplot(data.values,labels=['SepalLength','SepalWidth','PetalLength','PetalWidth'])
#
# File c:\Users\ronit\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2456, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2446 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2447 def boxplot(
#    2448         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2454         whiskerprops=None, manage_ticks=True, autorange=False,
# ...
